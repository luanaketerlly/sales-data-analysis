# %% [markdown]
# # Análise Comercial - Financial Dataset
# **Objetivo:**
# *   Analisar o desempenho de vendas
# *   Onde a empresa mais vende
# *   Onde mais lucra
# *   Onde está perdendo margem
# *   O impacto dos descontos
# *   Quais produtos e segmentos são mais estratégicos
# *   Como o desempenho evolui ao longo do tempo
#
#
#
#
#
#
#
# **Descrição do dataset:**
# O dataset contém informações de vendas, produtos, unidades vendidas, descontos, lucros e datas de transação.

# %% [markdown]
# ##Documentação de projeto
#
#
# [Clique aqui para abrir o PDF com resumo sobre o Dataset](https://drive.google.com/file/d/1Satg7MCapRGK4G9A2w0VmBhAGzlQz_as/view?usp=drive_link)

# %% [markdown]
# ##Importação de bibliotecas / arquivo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
#Configurações gráficas
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Projeto-analise-vendas/data/raw/dataset_original.csv')

# %% [markdown]
# ##Checagem de Dataset

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# 0   $16,185.00    $16,185.00   01/01/2014             1     January   2014
# 1   $13,210.00    $13,210.00   01/01/2014             1     January   2014
# 2   $21,780.00    $10,890.00   01/06/2014             6        June   2014
# 3    $8,880.00     $4,440.00   01/06/2014             6        June   2014
# 4   $24,700.00    $12,350.00   01/06/2014             6        June   2014

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
#  14   Month Name            700 non-null    object
#  15  Year                   700 non-null    int64
# dtypes: int64(2), object(14)
# memory usage: 87.6+ KB

# %%
df.describe()
# Out:
#        Month Number         Year
# count    700.000000   700.000000
# mean       7.900000  2013.750000
# std        3.377321     0.433322
# min        1.000000  2013.000000
# 25%        5.750000  2013.750000
# 50%        9.000000  2014.000000
# 75%       10.250000  2014.000000
# max       12.000000  2014.000000

# %%
df.isnull().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
#  Units Sold              0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
df.shape
# Out:
# (700, 16)

# %%
df.tail()
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold   Manufacturing Price   Sale Price     Gross Sales   \
# 695   $2,475.00               $260.00      $300.00    $7,42,500.00
# 696     $546.00               $260.00      $300.00    $1,63,800.00
# 697   $1,368.00                 $5.00        $7.00       $9,576.00
# 698     $723.00                $10.00        $7.00       $5,061.00
# 699   $1,806.00               $250.00       $12.00      $21,672.00
#
#          Discounts           Sales            COGS        Profit         Date  \
# 695   $1,11,375.00    $6,31,125.00    $6,18,750.00    $12,375.00   01/03/2014
# 696     $24,570.00    $1,39,230.00    $1,36,500.00     $2,730.00   01/10/2014
# 697      $1,436.40       $8,139.60       $6,840.00     $1,299.60   01/02/2014
# 698        $759.15       $4,301.85       $3,615.00       $686.85   01/04/2014
# 699      $3,250.80      $18,421.20       $5,418.00    $13,003.20   01/05/2014
#
#      Month Number  Month Name   Year
# 695             3       March   2014
# 696            10     October   2014
# 697             2    February   2014
# 698             4       April   2014
# 699             5         May   2014

# %% [markdown]
# # Tratamento de Dados
#
#
# 1.   Limpeza de colunas financeiras
# 2.  Conversão de dados de colunas
# 1. Criação de novas colunas

# %% [markdown]
# ##Parte 1 - Limpeza de colunas financeiras

# %%
#Verificando dados do Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
#  14   Month Name            700 non-null    object
#  15  Year                   700 non-null    int64
# dtypes: int64(2), object(14)
# memory usage: 87.6+ KB

# %%
#Verificando dados nulos do Dataset
df.isnull().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
#  Units Sold              0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
#Verificando dados do Dataset
df.describe()
# Out:
#        Month Number         Year
# count    700.000000   700.000000
# mean       7.900000  2013.750000
# std        3.377321     0.433322
# min        1.000000  2013.000000
# 25%        5.750000  2013.750000
# 50%        9.000000  2014.000000
# 75%       10.250000  2014.000000
# max       12.000000  2014.000000

# %%
#Removendo espaços extras dos nomes das colunas
df.columns = df.columns.str.strip().str.replace(' ', '_')

# %%
#Verificando se os espaços foram removidos
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold',
#        'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month_Number', 'Month_Name',
#        'Year'],
#       dtype='object')

# %%
#Conferindo a remoção dos símbolos
df.head(10)
# Out:
#             Segment  Country      Product Discount_Band   Units_Sold  \
# 0        Government   Canada   Carretera          None    $1,618.50
# 1        Government  Germany   Carretera          None    $1,321.00
# 2         Midmarket   France   Carretera          None    $2,178.00
# 3         Midmarket  Germany   Carretera          None      $888.00
# 4         Midmarket   Mexico   Carretera          None    $2,470.00
# 5        Government  Germany   Carretera          None    $1,513.00
# 6         Midmarket  Germany     Montana          None      $921.00
# 7  Channel Partners   Canada     Montana          None    $2,518.00
# 8        Government   France     Montana          None    $1,899.00
# 9  Channel Partners  Germany     Montana          None    $1,545.00
#
#   Manufacturing_Price Sale_Price     Gross_Sales Discounts           Sales  \
# 0              $3.00     $20.00      $32,370.00      $-        $32,370.00
# 1              $3.00     $20.00      $26,420.00      $-        $26,420.00
# 2              $3.00     $15.00      $32,670.00      $-        $32,670.00
# 3              $3.00     $15.00      $13,320.00      $-        $13,320.00
# 4              $3.00     $15.00      $37,050.00      $-        $37,050.00
# 5              $3.00    $350.00    $5,29,550.00      $-      $5,29,550.00
# 6              $5.00     $15.00      $13,815.00      $-        $13,815.00
# 7              $5.00     $12.00      $30,216.00      $-        $30,216.00
# 8              $5.00     $20.00      $37,980.00      $-        $37,980.00
# 9              $5.00     $12.00      $18,540.00      $-        $18,540.00
#
#              COGS          Profit        Date  Month_Number  Month_Name  Year
# 0     $16,185.00      $16,185.00   01/01/2014             1    January   2014
# 1     $13,210.00      $13,210.00   01/01/2014             1    January   2014
# 2     $21,780.00      $10,890.00   01/06/2014             6       June   2014
# 3      $8,880.00       $4,440.00   01/06/2014             6       June   2014
# 4     $24,700.00      $12,350.00   01/06/2014             6       June   2014
# 5   $3,93,380.00    $1,36,170.00   01/12/2014            12   December   2014
# 6      $9,210.00       $4,605.00   01/03/2014             3      March   2014
# 7      $7,554.00      $22,662.00   01/06/2014             6       June   2014
# 8     $18,990.00      $18,990.00   01/06/2014             6       June   2014
# 9      $4,635.00      $13,905.00   01/06/2014             6       June   2014

# %%
#Verificando valores nulos
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount_Band          0
# Units_Sold             0
# Manufacturing_Price    0
# Sale_Price             0
# Gross_Sales            0
# Discounts              0
# Sales                  0
# COGS                   0
# Profit                 0
# Date                   0
# Month_Number           0
# Month_Name             0
# Year                   0
# dtype: int64

# %%
#Verificando a quantidade de valores únicos em cada coluna
df.nunique()
# Out:
# Segment                  5
# Country                  5
# Product                  6
# Discount_Band            4
# Units_Sold             510
# Manufacturing_Price      6
# Sale_Price               7
# Gross_Sales            550
# Discounts              515
# Sales                  559
# COGS                   545
# Profit                 557
# Date                    16
# Month_Number            12
# Month_Name              12
# Year                     2
# dtype: int64

# %%
#Transformando valores nulos representados por '-' em nan para que não influencie no andamento do projeto
import numpy as np

df['Discounts'] = df['Discounts'].str.strip()
df['Discounts'] = df['Discounts'].replace('-', np.nan)

# %%
#Verificando alteração de valores nulos na coluna 'Discounts'
df.head()
# Out:
#       Segment  Country      Product Discount_Band   Units_Sold  \
# 0  Government   Canada   Carretera          None    $1,618.50
# 1  Government  Germany   Carretera          None    $1,321.00
# 2   Midmarket   France   Carretera          None    $2,178.00
# 3   Midmarket  Germany   Carretera          None      $888.00
# 4   Midmarket   Mexico   Carretera          None    $2,470.00
#
#   Manufacturing_Price Sale_Price   Gross_Sales Discounts         Sales  \
# 0              $3.00     $20.00    $32,370.00         $-   $32,370.00
# 1              $3.00     $20.00    $26,420.00         $-   $26,420.00
# 2              $3.00     $15.00    $32,670.00         $-   $32,670.00
# 3              $3.00     $15.00    $13,320.00         $-   $13,320.00
# 4              $3.00     $15.00    $37,050.00         $-   $37,050.00
#
#            COGS        Profit        Date  Month_Number Month_Name  Year
# 0   $16,185.00    $16,185.00   01/01/2014             1   January   2014
# 1   $13,210.00    $13,210.00   01/01/2014             1   January   2014
# 2   $21,780.00    $10,890.00   01/06/2014             6      June   2014
# 3    $8,880.00     $4,440.00   01/06/2014             6      June   2014
# 4   $24,700.00    $12,350.00   01/06/2014             6      June   2014

# %% [markdown]
# ##Parte 2 - Conversão de dados de colunas

# %%
import numpy as np

# Definindo uma função para limpar strings numéricas
def clean_numeric_string(value):
    if isinstance(value, str):
      # Remove todos os espaços
        value = value.strip().replace(' ', '')
        # TRansformando números com parênteses para números negativos: (X) -> -X
        if value.startswith('(') and value.endswith(')'):
            value = '-' + value[1:-1]
       # Removendo todos os caracteres não numéricos restantes, exceto o ponto decimal
        value = value.replace('$', '').replace(',', '')
        # Explicitamente tratando '-' como NaN após outras substituições
        if value == '-':
            return np.nan
        # Convertendo strings vazias em NaN
        if value == '':
            return np.nan
    return value

colunas = ['Units_Sold', 'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts', 'Sales', 'COGS', 'Profit']

# Aplica a função de limpeza a cada coluna.
for col in colunas:
    df[col] = df[col].apply(clean_numeric_string)

# Converte as colunas limpas para o formato float.
df[colunas] = df[colunas].apply(pd.to_numeric, errors='coerce')

# %%
colunas_monetarias = ['Units_Sold','Manufacturing_Price','Sale_Price',
                      'Gross_Sales','Discounts','Sales','COGS','Profit']

for col in colunas_monetarias:
    df[col] = (
        df[col]
        .astype(str)
        .str.strip()
        .replace(r'\$-', '0', regex=True)   # trata "$-" como zero
        .replace(r'[\$,]', '', regex=True)  # remove $ e vírgula
        .astype(float)
    )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount_Band        700 non-null    object
#  4   Units_Sold           700 non-null    float64
#  5   Manufacturing_Price  700 non-null    float64
#  6   Sale_Price           700 non-null    float64
#  7   Gross_Sales          700 non-null    float64
#  8   Discounts            647 non-null    float64
#  9   Sales                700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               637 non-null    float64
#  12  Date                 700 non-null    object
#  13  Month_Number         700 non-null    int64
#  14  Month_Name           700 non-null    object
#  15  Year                 700 non-null    int64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 87.6+ KB

# %%
#Verificando tipos de variáveis (colunas)
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount_Band           object
# Units_Sold             float64
# Manufacturing_Price    float64
# Sale_Price             float64
# Gross_Sales            float64
# Discounts              float64
# Sales                  float64
# COGS                   float64
# Profit                 float64
# Date                    object
# Month_Number             int64
# Month_Name              object
# Year                     int64
# dtype: object

# %%
#Alterando o tipo da coluna Date
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

# %%
#Corrigindo colunas derivadas de Date...
df['Month_Number'] = df['Date'].dt.month
df['Month_Name'] = df['Date'].dt.month_name()
df['Year'] = df['Date'].dt.year
df['Year_Month'] = df['Date'].dt.strftime('%Y-%m')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount_Band        700 non-null    object
#  4   Units_Sold           700 non-null    float64
#  5   Manufacturing_Price  700 non-null    float64
#  6   Sale_Price           700 non-null    float64
#  7   Gross_Sales          700 non-null    float64
#  8   Discounts            647 non-null    float64
#  9   Sales                700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               637 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month_Number         700 non-null    int32
#  14  Month_Name           700 non-null    object
#  15  Year                 700 non-null    int32
#  16  Year_Month           700 non-null    object
# dtypes: datetime64[ns](1), float64(8), int32(2), object(6)
# memory usage: 87.6+ KB

# %% [markdown]
# ##Parte 3 - Criação de novas colunas

# %%
#Criando a coluna "MARGEM"
#Definindo a fórmula com objetivo de obter a margem de lucro.
#A divisão Profit / Sales calcula a proporção do lucro em relação à receita.
df['Margin'] = df['Profit'] / df['Sales']

# %%
df['Margin'] = df['Profit'] / df['Sales']

# %%
df.sort_values(by='Margin', ascending=False).head(10)
# Out:
#              Segment                   Country     Product Discount_Band  \
# 20  Channel Partners                   Germany      Paseo          None
# 27  Channel Partners  United States of America      Paseo          None
# 33  Channel Partners                   Germany       Velo          None
# 50  Channel Partners  United States of America   Amarilla          None
# 46  Channel Partners  United States of America   Amarilla          None
# 35  Channel Partners                   Germany       Velo          None
# 39  Channel Partners                   Germany        VTT          None
# 9   Channel Partners                   Germany    Montana          None
# 7   Channel Partners                    Canada    Montana          None
# 18  Channel Partners                    Canada      Paseo          None
#
#     Units_Sold  Manufacturing_Price  Sale_Price  Gross_Sales  Discounts  \
# 20       367.0                 10.0        12.0       4404.0        NaN
# 27       912.0                 10.0        12.0      10944.0        NaN
# 33      2161.0                120.0        12.0      25932.0        NaN
# 50      2141.0                260.0        12.0      25692.0        NaN
# 46      1953.0                260.0        12.0      23436.0        NaN
# 35      1545.0                120.0        12.0      18540.0        NaN
# 39      2838.0                250.0        12.0      34056.0        NaN
# 9       1545.0                  5.0        12.0      18540.0        NaN
# 7       2518.0                  5.0        12.0      30216.0        NaN
# 18      2518.0                 10.0        12.0      30216.0        NaN
#
#       Sales    COGS   Profit       Date  Month_Number Month_Name  Year  \
# 20   4404.0  1101.0   3303.0 2014-07-01             7       July  2014
# 27  10944.0  2736.0   8208.0 2013-11-01            11   November  2013
# 33  25932.0  6483.0  19449.0 2014-03-01             3      March  2014
# 50  25692.0  6423.0  19269.0 2014-08-01             8     August  2014
# 46  23436.0  5859.0  17577.0 2014-04-01             4      April  2014
# 35  18540.0  4635.0  13905.0 2014-06-01             6       June  2014
# 39  34056.0  8514.0  25542.0 2014-04-01             4      April  2014
# 9   18540.0  4635.0  13905.0 2014-06-01             6       June  2014
# 7   30216.0  7554.0  22662.0 2014-06-01             6       June  2014
# 18  30216.0  7554.0  22662.0 2014-06-01             6       June  2014
#
#    Year_Month  Margin
# 20    2014-07    0.75
# 27    2013-11    0.75
# 33    2014-03    0.75
# 50    2014-08    0.75
# 46    2014-04    0.75
# 35    2014-06    0.75
# 39    2014-04    0.75
# 9     2014-06    0.75
# 7     2014-06    0.75
# 18    2014-06    0.75

# %%
df = df[df['Sales'] > 0]
df = df[df['Margin'] <= 1]

# %%
#Criando a coluna "TICKET MÉDIO POR UNIDADE"
#A divisão Sales / Units_Sold calcula o valor médio de cada unidade vendida quanto em média cada produto foi vendido.
df['Average_Ticket_Per_Unit'] = df['Sales'] / df['Units_Sold']

# %%
#Criando a coluna "ANO-MÊS(YYYY-MM)"
df['Year_Month'] = df['Date'].dt.strftime('%Y-%m') #,dt.strftime(('%Y-%m) formata cada data para o padrão ano-mês')

# %%
print (df['Year_Month'].unique())
# Out:
# ['2014-01' '2014-06' '2014-12' '2014-03' '2014-07' '2014-08' '2014-09'
#  '2013-10' '2014-02' '2013-09' '2014-10' '2013-11' '2013-12' '2014-04'
#  '2014-05' '2014-11']

# %%
#Criando coluna auxiliar para ordenação da data"
df['Year_Month']= df['Date'].dt.strftime('%Y-%m')
df['Year_Month_Sort']= df['Date'].dt.strftime('%Y%m').astype(int)

# %%
#Criando a coluna "INDICADOR DE DESCONTO (SIM=1/NÃO=0)"
#A função lambda verifica se a coluna Discounts possui valor maior que 0, se sim, preenche com Yes, Senão, Com No.
df['Discount_indicator'] = df['Discounts'].apply(lambda x: 'Yes' if x > 0 else 'No')

# %%
#Criando a coluna "PERCENTUAL DE DESCONTO"
#A divisão Discounts / Gross_Sales calcula a proporção do desconto em relação às vendas brutas.
df['Discount_percentage'] = (df['Discounts'] / df['Gross_Sales'])

# %%
#Conferindo se as colunas foram criadas corretamente
df.head()
# Out:
#       Segment  Country      Product Discount_Band  Units_Sold  \
# 0  Government   Canada   Carretera          None       1618.5
# 1  Government  Germany   Carretera          None       1321.0
# 2   Midmarket   France   Carretera          None       2178.0
# 3   Midmarket  Germany   Carretera          None        888.0
# 4   Midmarket   Mexico   Carretera          None       2470.0
#
#    Manufacturing_Price  Sale_Price  Gross_Sales  Discounts    Sales  ...  \
# 0                  3.0        20.0      32370.0        NaN  32370.0  ...
# 1                  3.0        20.0      26420.0        NaN  26420.0  ...
# 2                  3.0        15.0      32670.0        NaN  32670.0  ...
# 3                  3.0        15.0      13320.0        NaN  13320.0  ...
# 4                  3.0        15.0      37050.0        NaN  37050.0  ...
#
#         Date  Month_Number Month_Name  Year Year_Month    Margin  \
# 0 2014-01-01             1    January  2014    2014-01  0.500000
# 1 2014-01-01             1    January  2014    2014-01  0.500000
# 2 2014-06-01             6       June  2014    2014-06  0.333333
# 3 2014-06-01             6       June  2014    2014-06  0.333333
# 4 2014-06-01             6       June  2014    2014-06  0.333333
#
#   Average_Ticket_Per_Unit  Year_Month_Sort  Discount_indicator  \
# 0                    20.0           201401                  No
# 1                    20.0           201401                  No
# 2                    15.0           201406                  No
# 3                    15.0           201406                  No
# 4                    15.0           201406                  No
#
#    Discount_percentage
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 22 columns]

# %%
#Renomeando a coluna "MARGEM"
df.rename(columns={'Margin (%)': 'Margin'}, inplace=True)

# %%
#Verificando todas as colunas existentes no Dataset
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold',
#        'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month_Number', 'Month_Name', 'Year',
#        'Year_Month', 'Margin', 'Average_Ticket_Per_Unit', 'Year_Month_Sort',
#        'Discount_indicator', 'Discount_percentage'],
#       dtype='object')

# %%
#Conferindo tipos de colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637 entries, 0 to 699
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Segment                  637 non-null    object
#  1   Country                  637 non-null    object
#  2   Product                  637 non-null    object
#  3   Discount_Band            637 non-null    object
#  4   Units_Sold               637 non-null    float64
#  5   Manufacturing_Price      637 non-null    float64
#  6   Sale_Price               637 non-null    float64
#  7   Gross_Sales              637 non-null    float64
#  8   Discounts                584 non-null    float64
#  9   Sales                    637 non-null    float64
#  10  COGS                     637 non-null    float64
#  11  Profit                   637 non-null    float64
#  12  Date                     637 non-null    datetime64[ns]
#  13  Month_Number             637 non-null    int32
#  14  Month_Name               637 non-null    object
#  15  Year                     637 non-null    int32
#  16  Year_Month               637 non-null    object
#  17  Margin                   637 non-null    float64
#  18  Average_Ticket_Per_Unit  637 non-null    float64
#  19  Year_Month_Sort          637 non-null    int64
#  20  Discount_indicator       637 non-null    object
#  21  Discount_percentage      584 non-null    float64
# dtypes: datetime64[ns](1), float64(11), int32(2), int64(1), object(7)
# memory usage: 109.5+ KB

# %%
#Verificando colunas
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold',
#        'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month_Number', 'Month_Name', 'Year',
#        'Year_Month', 'Margin', 'Average_Ticket_Per_Unit', 'Year_Month_Sort',
#        'Discount_indicator', 'Discount_percentage'],
#       dtype='object')

# %%
#Conferindo tamanho final do Dataset (700 linhas, 21 colunas)
df.shape
# Out:
# (637, 22)

# %%
# ==============================
# VERIFICAÇÃO FINAL DO DATASET
# ==============================

# verificar estrutura
df.info()

# verificar valores nulos
print("\nValores nulos por coluna:")
print(df.isnull().sum())

# verificar duplicatas
print("\nLinhas duplicadas:", df.duplicated().sum())

# estatísticas das colunas numéricas
print("\nEstatísticas gerais:")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637 entries, 0 to 699
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Segment                  637 non-null    object
#  1   Country                  637 non-null    object
#  2   Product                  637 non-null    object
#  3   Discount_Band            637 non-null    object
#  4   Units_Sold               637 non-null    float64
#  5   Manufacturing_Price      637 non-null    float64
#  6   Sale_Price               637 non-null    float64
#  7   Gross_Sales              637 non-null    float64
#  8   Discounts                584 non-null    float64
#  9   Sales                    637 non-null    float64
#  10  COGS                     637 non-null    float64
#  11  Profit                   637 non-null    float64
#  12  Date                     637 non-null    datetime64[ns]
#  13  Month_Number             637 non-null    int32
#  14  Month_Name               637 non-null    object
#  15  Year                     637 non-null    int32
#  16  Year_Month               637 non-null    object
#  17  Margin                   637 non-null    float64
#  18  Average_Ticket_Per_Unit  637 non-null    float64
#  19  Year_Month_Sort          637 non-null    int64
#  20  Discount_indicator       637 non-null    object
#  21  Discount_percentage      584 non-null    float64
# dtypes: datetime64[ns](1), float64(11), int32(2), int64(1), object(7)
# memory usage: 109.5+ KB
#
# Valores nulos por coluna:
# Segment                     0
# Country                     0
# Product                     0
# Discount_Band               0
# Units_Sold                  0
# Manufacturing_Price         0
# Sale_Price                  0
# Gross_Sales                 0
# Discounts                  53
# Sales                       0
# COGS                        0
# Profit                      0
# Date                        0
# Month_Number                0
# Month_Name                  0
# Year                        0
# Year_Month                  0
# Margin                      0
# Average_Ticket_Per_Unit     0
# Year_Month_Sort             0
# Discount_indicator          0
# Discount_percentage        53
# dtype: int64
#
# Linhas duplicadas: 0
#
# Estatísticas gerais:
#         Units_Sold  Manufacturing_Price  Sale_Price   Gross_Sales  \
# count   637.000000           637.000000   637.00000  6.370000e+02
# mean   1593.654631            96.025118   117.77865  1.791218e+05
# min     200.000000             3.000000     7.00000  1.799000e+03
# 25%     888.000000             5.000000    12.00000  1.628900e+04
# 50%    1530.000000            10.000000    20.00000  3.250500e+04
# 75%    2181.000000           250.000000   300.00000  2.664000e+05
# max    4492.500000           260.000000   350.00000  1.207500e+06
# std     864.994775           108.747440   143.37345  2.640318e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     584.000000  6.370000e+02     637.000000     637.000000
# mean    13484.053116  1.667597e+05  139018.662480   27741.010267
# min        18.410000  1.655080e+03     918.000000     285.600000
# 25%       908.750000  1.471470e+04    7026.000000    3875.850000
# 50%      2531.760000  3.018400e+04   18990.000000   11106.100000
# 75%     13328.000000  2.435912e+05  222000.000000   25162.000000
# max    149677.500000  1.159200e+06  950625.000000  262200.000000
# std     24290.271204  2.460009e+05  210034.523549   43059.332905
#
#                                 Date  Month_Number         Year      Margin  \
# count                            637    637.000000   637.000000  637.000000
# mean   2014-04-28 23:21:34.191522816      7.916797  2013.748823    0.312769
# min              2013-09-01 00:00:00      1.000000  2013.000000    0.010309
# 25%              2013-12-01 00:00:00      6.000000  2013.000000    0.159664
# 50%              2014-06-01 00:00:00      9.000000  2014.000000    0.248120
# 75%              2014-09-01 00:00:00     10.000000  2014.000000    0.450549
# max              2014-12-01 00:00:00     12.000000  2014.000000    0.750000
# std                              NaN      3.351192     0.434031    0.217761
#
#        Average_Ticket_Per_Unit  Year_Month_Sort  Discount_percentage
# count               637.000000       637.000000           584.000000
# mean                109.471209    201382.799058             0.077654
# min                   5.950000    201309.000000             0.010000
# 25%                  11.400000    201312.000000             0.040000
# 50%                  17.600000    201406.000000             0.080000
# 75%                 273.000000    201409.000000             0.110000
# max                 350.000000    201412.000000             0.150000
# std                 133.086402        42.087739             0.042946

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637 entries, 0 to 699
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Segment                  637 non-null    object
#  1   Country                  637 non-null    object
#  2   Product                  637 non-null    object
#  3   Discount_Band            637 non-null    object
#  4   Units_Sold               637 non-null    float64
#  5   Manufacturing_Price      637 non-null    float64
#  6   Sale_Price               637 non-null    float64
#  7   Gross_Sales              637 non-null    float64
#  8   Discounts                584 non-null    float64
#  9   Sales                    637 non-null    float64
#  10  COGS                     637 non-null    float64
#  11  Profit                   637 non-null    float64
#  12  Date                     637 non-null    datetime64[ns]
#  13  Month_Number             637 non-null    int32
#  14  Month_Name               637 non-null    object
#  15  Year                     637 non-null    int32
#  16  Year_Month               637 non-null    object
#  17  Margin                   637 non-null    float64
#  18  Average_Ticket_Per_Unit  637 non-null    float64
#  19  Year_Month_Sort          637 non-null    int64
#  20  Discount_indicator       637 non-null    object
#  21  Discount_percentage      584 non-null    float64
# dtypes: datetime64[ns](1), float64(11), int32(2), int64(1), object(7)
# memory usage: 109.5+ KB

# %%
df.nunique()
# Out:
# Segment                      5
# Country                      5
# Product                      6
# Discount_Band                4
# Units_Sold                 465
# Manufacturing_Price          6
# Sale_Price                   7
# Gross_Sales                498
# Discounts                  462
# Sales                      504
# COGS                       493
# Profit                     505
# Date                        16
# Month_Number                12
# Month_Name                  12
# Year                         2
# Year_Month                  16
# Margin                     154
# Average_Ticket_Per_Unit    135
# Year_Month_Sort             16
# Discount_indicator           2
# Discount_percentage         36
# dtype: int64

# %% [markdown]
# #Análise exploratória
#
# **Pontos de análise:**
# *   Qual país vende mais?
# *   Qual país é mais lucrativo?
# *   Qual segmento gera mais lucro?
# *   Qual produto tem maior margem?
# *   Descontos aumentam ou reduzem lucro?
# *   Existe sazonalidade?
# *   Existe produto que vende muito mas gera pouco?

# %% [markdown]
# ##Qual país vende mais?
# -	United States of America

# %%
# Agrupar vendas por país e transferir para 'vendas_por_pais' deixando ordenado
vendas_por_pais = df.groupby('Country')['Sales'].sum().sort_values(ascending=False)

# Cores em verde
cores = ['#2e7d32' if i == 0 else '#a5d6a7' for i in range(len(vendas_por_pais))]

# Criar gráfico de barras
grafico1 = plt.figure()
vendas_por_pais.plot(kind='bar', color=cores)

# Títulos
plt.title('Vendas por País')
plt.xlabel('País')
plt.ylabel('Total de Vendas')

# Ajustes visuais
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar valores nas barras
for i, v in enumerate(vendas_por_pais):
    plt.text(i, v, str(round(v, 2)), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##Qual país é mais lucrativo?
#
# -United States of America

# %%
# Agrupando os lucros por país e ordenando
lucro_pais = df.groupby('Country')['Profit'].sum().sort_values(ascending=False)

# Cores em verde
cores = ['#2e7d32' if i == 0 else '#a5d6a7' for i in range(len(vendas_por_pais))]

# Criar gráfico de barras
grafico2 = plt.figure()
vendas_por_pais.plot(kind='bar', color=cores)

# Títulos
plt.title('Lucro por País')
plt.xlabel('País')
plt.ylabel('Lucro')

# Ajuste visual
plt.xticks(rotation=45)
plt.tight_layout()

# Rotacionar nomes dos países (se necessário)
plt.xticks(rotation=45)

# Exibir
plt.show()

# %% [markdown]
# ##Qual segmento gera mais lucro?
# -Government

# %%
# Agrupar lucro por segmento
lucro_segmento = df.groupby('Segment')['Profit'].sum().sort_values(ascending=False)

# Ver no console
print(lucro_segmento)

# Cores em verde (destacar o mais lucrativo)
cores = ['#2e7d32' if i == 0 else '#a5d6a7' for i in range(len(lucro_segmento))]

# Criar gráfico
grafico3 = plt.figure()
lucro_segmento.plot(kind='bar', color=cores)

# Títulos
plt.title('Lucro por Segmento')
plt.xlabel('Segmento')
plt.ylabel('Lucro Total')

# Ajustes visuais
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar valores nas barras
for i, v in enumerate(lucro_segmento):
    plt.text(i, v, str(round(v, 2)), ha='center', va='bottom')

plt.show()
# Out:
# Segment
# Government          11388173.18
# Small Business       4143168.50
# Channel Partners     1316803.14
# Midmarket             660103.09
# Enterprise            162775.63
# Name: Profit, dtype: float64

# %% [markdown]
# ##Qual produto tem maior margem? (Equilíbrio = margem x venda)
# -Paseo

# %%
# Agrupar por produto
analise_produto = df.groupby('Product').agg({
    'Sales': 'sum',
    'Margin': 'mean'
})

# Normalizar (colocar na mesma escala 0 a 1)
analise_produto['Sales_norm'] = (analise_produto['Sales'] - analise_produto['Sales'].min()) / (analise_produto['Sales'].max() - analise_produto['Sales'].min())

analise_produto['Margin_norm'] = (analise_produto['Margin'] - analise_produto['Margin'].min()) / (analise_produto['Margin'].max() - analise_produto['Margin'].min())

# Criar score combinado
analise_produto['Score'] = analise_produto['Sales_norm'] + analise_produto['Margin_norm']

# Ordenar
analise_produto = analise_produto.sort_values(by='Score', ascending=False)

# Mostrar resultado
print(analise_produto)
# Out:
#                   Sales    Margin  Sales_norm  Margin_norm     Score
# Product
# Paseo       29945452.71  0.309829    1.000000     0.298176  1.298176
# Carretera   11257917.89  0.352293    0.000000     1.000000  1.000000
# Amarilla    15909756.07  0.331680    0.248927     0.659317  0.908245
# Velo        16091795.72  0.308274    0.258669     0.272478  0.531147
# VTT         19220421.02  0.291787    0.426086     0.000000  0.426086
# Montana     13800568.13  0.293380    0.136061     0.026330  0.162391

# %%
# Cores
cores = ['#2e7d32' if i == 0 else '#a5d6a7' for i in range(len(analise_produto))]

grafico4 = plt.figure()
analise_produto['Score'].plot(kind='bar', color=cores)

plt.title('Produtos com Melhor Equilíbrio: Margem x Vendas')
plt.xlabel('Produto')
plt.ylabel('Score (Margem + Volume)')

plt.xticks(rotation=45)
plt.tight_layout()

# Valores nas barras
for i, v in enumerate(analise_produto['Score']):
    plt.text(i, v, str(round(v, 2)), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##Descontos aumentam ou reduzem lucro?
# -Os descontos diminuem o lucro.

# %%
# Agrupando valores
lucro_desconto = df.groupby('Discount_Band')['Profit'].mean()

# Ordenando resultados
lucro_desconto = lucro_desconto.sort_values(ascending=False)

# Mostrar no console
print(lucro_desconto)

# Cores em verde (destacar melhor faixa)
cores = ['#2e7d32' if i == 0 else '#a5d6a7' for i in range(len(lucro_desconto))]

# Gráfico
grafico5 = plt.figure()
lucro_desconto.plot(kind='bar', color=cores)

plt.title('Impacto do Desconto no Lucro')
plt.xlabel('Faixa de Desconto')
plt.ylabel('Lucro Médio')

plt.xticks(rotation=45)
plt.tight_layout()

# Valores nas barras
for i, v in enumerate(lucro_desconto):
    plt.text(i, v, str(round(v, 2)), ha='center', va='bottom')

plt.show()
# Out:
# Discount_Band
# Low        39928.114258
# None       32763.301887
# Medium     26426.153641
# High       18920.922123
# Name: Profit, dtype: float64

# %% [markdown]
# ##Existe sazonalidade?
# -Tendo em vista que a base de dados só tem registros do ano de 2013 a partir do mês de Setembro; As vendas apresentam uma leve sazonalidade, com picos em meses semelhantes entre os anos analisados.

# %%
#Criando uma base de vendas por ano
pivot = df.pivot_table(
    values='Units_Sold',
    index='Month_Number',
    columns='Year',
    aggfunc='sum'
)

# %%
#Criando o gráfico comparativo entre os anos
grafico6 = plt.figure()

for ano in pivot.columns:
    plt.plot(pivot.index, pivot[ano], marker='o', label=ano)
#Criando os títulos do gráfico
plt.title('Comparativo de Vendas por Mês ao Longo dos Anos')
plt.xlabel('Mês')
plt.ylabel('Unidades Vendidas')
#Parte visual do gráfico
plt.xticks(range(1, 13))
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Existe produto que vende muito mas gera pouco?
# -Não, todos os produtos apresentam um bom índice de lucro comparado ás vendas.

# %%
#Criando listagem de vendas e lucro por produto
analise_produto = df.groupby('Product').agg({
    'Units_Sold': 'sum',
    'Profit': 'sum'
})

print(analise_produto)
# Out:
#             Units_Sold      Profit
# Product
# Amarilla      138987.5  2936044.07
# Carretera     123608.5  2057914.89
# Montana       140475.0  2171281.13
# Paseo         311687.5  4917986.71
# VTT           157006.0  3156348.02
# Velo          143393.5  2431448.72

# %%
# Ordenando por vendas (Units_Sold)
analise_produto = analise_produto.sort_values(by='Units_Sold', ascending=False)

# Posições no eixo X
x = np.arange(len(analise_produto))

# Largura das barras
width = 0.35

grafico7 = plt.figure()

# Barras
plt.bar(x - width/2, analise_produto['Units_Sold'], width, label='Vendas')
plt.bar(x + width/2, analise_produto['Profit'], width, label='Lucro')

# Títulos
plt.title('Ranking de Produtos: Vendas x Lucro')
plt.xlabel('Produto')
plt.ylabel('Valores')

plt.xticks(x, analise_produto.index, rotation=45)

plt.legend()
plt.tight_layout()

plt.show()

# %%
# =======================================
# VERIFICAÇÃO FINAL DO DATASET
# =======================================
df.dtypes
# Out:
# Segment                            object
# Country                            object
# Product                            object
# Discount_Band                      object
# Units_Sold                        float64
# Manufacturing_Price               float64
# Sale_Price                        float64
# Gross_Sales                       float64
# Discounts                         float64
# Sales                             float64
# COGS                              float64
# Profit                            float64
# Date                       datetime64[ns]
# Month_Number                        int32
# Month_Name                         object
# Year                                int32
# Year_Month                         object
# Margin                            float64
# Average_Ticket_Per_Unit           float64
# Year_Month_Sort                     int64
# Discount_indicator                 object
# Discount_percentage               float64
# dtype: object

# %%
# ====================================
#VERIFICAÇÃO FINAL DO DATASET
# ====================================
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 637 entries, 0 to 699
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Segment                  637 non-null    object
#  1   Country                  637 non-null    object
#  2   Product                  637 non-null    object
#  3   Discount_Band            637 non-null    object
#  4   Units_Sold               637 non-null    float64
#  5   Manufacturing_Price      637 non-null    float64
#  6   Sale_Price               637 non-null    float64
#  7   Gross_Sales              637 non-null    float64
#  8   Discounts                584 non-null    float64
#  9   Sales                    637 non-null    float64
#  10  COGS                     637 non-null    float64
#  11  Profit                   637 non-null    float64
#  12  Date                     637 non-null    datetime64[ns]
#  13  Month_Number             637 non-null    int32
#  14  Month_Name               637 non-null    object
#  15  Year                     637 non-null    int32
#  16  Year_Month               637 non-null    object
#  17  Margin                   637 non-null    float64
#  18  Average_Ticket_Per_Unit  637 non-null    float64
#  19  Year_Month_Sort          637 non-null    int64
#  20  Discount_indicator       637 non-null    object
#  21  Discount_percentage      584 non-null    float64
# dtypes: datetime64[ns](1), float64(11), int32(2), int64(1), object(7)
# memory usage: 109.5+ KB

# %%
# =================================
# VERIFICAÇÃO FINAL DO DATASET
# =================================
print(df.columns.tolist())
# Out:
# ['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold', 'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts', 'Sales', 'COGS', 'Profit', 'Date', 'Month_Number', 'Month_Name', 'Year', 'Year_Month', 'Margin', 'Average_Ticket_Per_Unit', 'Year_Month_Sort', 'Discount_indicator', 'Discount_percentage']

# %%
# ==============================
# EXPORTAR DATASET TRATADO
# ==============================
#df.to_csv('/content/drive/MyDrive/Projeto-analise-vendas/data/processed/dataset_tratado_15.csv',
          #sep=';',
          #decimal=',',
          #index=False,
          #encoding='utf-8-sig')
#print("Dataset tratado salvo com sucesso no Google Drive.")
# Out:
# Dataset tratado salvo com sucesso no Google Drive.

# %%
#from google.colab import files
#files.download('/content/drive/MyDrive/Projeto-analise-vendas/data/processed/dataset_tratado_15.csv')
